# %%
# iterations: gamma(1,0.5) pair with correlation 0, 0.25, 0.5, 0.75, 0.99
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
import matplotlib.ticker as tck
# from matplotlib.ticker import MultipleLocator
import numpy as np
iter0_bl = [3671,4252,14902,3807,4701,4603,7951,2203,5402,3251,2753,3601,2433,2801,8601]
iter0_lb = [2001,2751,7151,2551,2201,2851,3001,1951,2651,2001,2801,2201,1801,1901,17351]
iter25_bl = [4802, 3952, 9306, 2562, 1935, 3601, 3453, 8601, 3407, 2501, 2855, 2551, 2154, 3801, 18401]
iter25_lb = [2951, 2101, 5351, 2701, 1901, 4101, 2151, 1901, 2451, 1601, 2051, 1651, 1651, 2351, 16801]
iter5_bl = [1902, 7802, 2251, 3404, 11001, 6601, 3802, 6551, 2955, 2008, 2901, 2101, 2815, 17100, 4301]
iter5_lb = [1701, 1751, 2051, 1551, 2201, 3701, 1951, 1651, 2551, 1601, 2301, 1601, 2051, 2251, 7901]
iter75_bl = [2601, 3051, 5602, 2852, 6751, 5802, 4852, 2556, 9151, 1952, 3751, 2702, 3004, 3601, 8751]
iter75_lb = [1651, 1651, 6051, 1651, 2301, 11801, 3851, 1551, 3851, 1551, 4201, 1601, 1651, 1501, 1501]
iter99_bl = [2552, 3151, 1901, 1253, 2152, 3201, 1656, 1751, 1652, 1652, 1651, 1602, 2001, 2151, 2152]
iter99_lb = [1551, 1601, 1054, 1051, 1601, 1701, 1251, 1055, 1151, 1551, 1301, 1151, 1301, 1551, 1801]
data_a = [iter0_bl,iter25_bl,iter5_bl,iter75_bl,iter99_bl]
data_b = [iter0_lb,iter25_lb,iter5_lb,iter75_lb,iter99_lb]
ticks = [r'$\rho=0$', r'$\rho=0.25$', r'$\rho=0.5$',r'$\rho=0.75$',r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0-0.2, sym='', widths=0.35)
bpr = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0+0.2, sym='', widths=0.35)
# set_box_color(bpl, '#2c7fb8') # colors are from http://colorbrewer2.org/
# set_box_color(bpr, '#D7191C')
set_box_color(bpl, '#0000FF') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#FF0000')

# draw temporary red and blue lines and use them to create a legend
# plt.plot([], c='#2C7BB6', label='baseline SINN')
# plt.plot([], c='#2c7fb8', label='baseline SINN')
# plt.plot([], c='#D7191C', label='loss-balanced SINN')
plt.plot([], c='#0000FF', label='baseline SINN')
plt.plot([], c='#FF0000', label='loss-balanced SINN')

plt.legend(frameon=False)
plt.gca().yaxis.set_minor_locator(tck.AutoMinorLocator())
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 12000)
plt.xlabel('Correlations')
plt.ylabel('Number of Iterations')
plt.tight_layout()

# %%
# overhead: gamma(1,0.5) pair with correlation 0, 0.25, 0.5, 0.75, 0.99
oh0_bl = [219.78, 254.89, 891.85, 228.09, 281.58, 275.89, 476.24, 132.19, 323.69, 194.82, 165.22, 216.1, 145.88, 168.01, 515.48]
oh0_lb = [148.23, 203.24, 527.62, 188.36, 162.56, 210.65, 221.66, 144.21, 195.95, 147.94, 207.06, 162.68, 133.21, 140.59, 1281.65]
oh25_bl = [287.55, 236.47, 556.33, 153.35, 115.76, 215.56, 206.74, 514.54, 203.97, 149.78, 171.11, 152.81, 129.07, 227.75, 1100.99]
oh25_lb = [217.96, 155.24, 395.17, 199.47, 140.47, 302.83, 158.85, 140.56, 181.04, 118.34, 151.7, 122.06, 122.09, 173.62, 1240.19]
oh5_bl = [114.11, 467.03, 134.87, 203.93, 658.62, 395.48, 227.89, 392.35, 177.11, 120.56, 174.01, 126.16, 168.78, 1024.74, 258.41]
oh5_lb = [126.57, 129.49, 151.55, 114.67, 162.73, 273.29, 144.22, 121.97, 188.42, 118.46, 170.77, 118.46, 151.67, 166.6, 583.71]
oh75_bl = [155.79, 182.78, 335.31, 170.76, 403.92, 347.07, 290.48, 153.13, 547.64, 117.07, 224.63, 161.84, 180.1, 215.83, 523.93]
oh75_lb = [122.18, 122.28, 447.36, 122.28, 170.18, 871.47, 284.55, 114.85, 284.55, 114.92, 310.62, 118.42, 122.27, 111.16, 111.25]
oh99_bl = [153.24, 189.19, 114.32, 75.37, 129.42, 192.22, 99.59, 105.28, 99.35, 99.29, 99.21, 96.37, 120.36, 129.3, 129.32]
oh99_lb = [114.8, 118.55, 78.15, 77.87, 118.56, 125.92, 92.71, 78.26, 85.27, 114.94, 96.3, 85.39, 96.29, 114.91, 133.18]
data_c = [oh0_bl,oh25_bl,oh5_bl,oh75_bl,oh99_bl]
data_d = [oh0_lb,oh25_lb,oh5_lb,oh75_lb,oh99_lb]
ticks = [r'$\rho=0$', r'$\rho=0.25$', r'$\rho=0.5$',r'$\rho=0.75$',r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_c, positions=np.array(range(len(data_a)))*2.0-0.2, sym='', widths=0.35)
bpr = plt.boxplot(data_d, positions=np.array(range(len(data_b)))*2.0+0.2, sym='', widths=0.35)
set_box_color(bpl, '#0000FF') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#FF0000')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#0000FF', label='baseline SINN')
plt.plot([], c='#FF0000', label='loss-balanced SINN')
plt.legend(frameon=False)
plt.gca().yaxis.set_minor_locator(tck.AutoMinorLocator())
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 700)
plt.xlabel('Correlations')
plt.ylabel('Total Computational Time (s)')
plt.tight_layout()

# %%
# iterations: gamma(1,1) pair with correlation 0, 0.5, 0.99

# uncorrelated 
iter_1 = np.loadtxt('iter_pair1_uncorr_baseline.txt')
iter_2 = np.loadtxt('iter_pair1_uncorr_AW.txt')
# correlation = 0.5
iter_3 = np.loadtxt('iter_pair1_0.5corr_baseline.txt')
iter_4 = np.loadtxt('iter_pair1_0.5corr_AW.txt')
# correlation = 0.99
iter_5 = np.loadtxt('iter_pair1_0.99corr_baseline.txt')
iter_6 = np.loadtxt('iter_pair1_0.99corr_AW.txt')

data_a1 = [iter_1,iter_3,iter_5]
data_b1 = [iter_2,iter_4,iter_6]
ticks = [r'$\rho=0$', r'$\rho=0.5$', r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(frameon=False)

bpl = plt.boxplot(data_a1, positions=np.array(range(len(data_a1)))*2.0-0.2, sym='', widths=0.4)
bpr = plt.boxplot(data_b1, positions=np.array(range(len(data_b1)))*2.0+0.2, sym='', widths=0.4)
# set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
# set_box_color(bpr, '#2C7BB6')
set_box_color(bpl, '#0000FF') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#FF0000')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#0000FF', label='baseline SINN')
plt.plot([], c='#FF0000', label='loss-balanced SINN')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
# plt.ylim(0, 8)
plt.tight_layout()

# %%
# overhead: gamma(1,1) pair with correlation 0, 0.5, 0.99

# uncorrelated 
oh_1 = np.loadtxt('overhead_pair1_uncorr_baseline.txt')
oh_2 = np.loadtxt('overhead_pair1_uncorr_AW.txt')
# correlation = 0.5
oh_3 = np.loadtxt('overhead_pair1_0.5corr_baseline.txt')
oh_4 = np.loadtxt('overhead_pair1_0.5corr_AW.txt')
# correlation = 0.99
oh_5 = np.loadtxt('overhead_pair1_0.99corr_baseline.txt')
oh_6 = np.loadtxt('overhead_pair1_0.99corr_AW.txt')

data_c1 = [oh_1,oh_3,oh_5]
data_d1 = [oh_2,oh_4,oh_6]
ticks = [r'$\rho=0$', r'$\rho=0.5$', r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_c1, positions=np.array(range(len(data_c1)))*2.0-0.2, sym='', widths=0.4)
bpr = plt.boxplot(data_d1, positions=np.array(range(len(data_d1)))*2.0+0.2, sym='', widths=0.4)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='baseline SINN')
plt.plot([], c='#2C7BB6', label='loss-balanced SINN')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
# plt.ylim(0, 8)
plt.tight_layout()

# %%
# iterations: gamma(1,2) pair with correlation 0, 0.5, 0.99

# uncorrelated 
iter_1 = np.loadtxt('iter_pair2_uncorr_baseline.txt')
iter_2 = np.loadtxt('iter_pair2_uncorr_AW.txt')
# correlation = 0.5
iter_3 = np.loadtxt('iter_pair2_0.5corr_baseline.txt')
iter_4 = np.loadtxt('iter_pair2_0.5corr_AW.txt')
# correlation = 0.99
iter_5 = np.loadtxt('iter_pair2_0.99corr_baseline.txt')
iter_6 = np.loadtxt('iter_pair2_0.99corr_AW.txt')

data_a2 = [iter_1,iter_3,iter_5]
data_b2 = [iter_2,iter_4,iter_6]
ticks = [r'$\rho=0$', r'$\rho=0.5$', r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_a2, positions=np.array(range(len(data_a2)))*2.0-0.2, sym='', widths=0.4)
bpr = plt.boxplot(data_b2, positions=np.array(range(len(data_b2)))*2.0+0.2, sym='', widths=0.4)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='baseline SINN')
plt.plot([], c='#2C7BB6', label='loss-balanced SINN')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
# plt.ylim(0, 8)
plt.tight_layout()

# %%
# overhead: gamma(1,2) pair with correlation 0, 0.5, 0.99

# uncorrelated 
oh_1 = np.loadtxt('overhead_pair2_uncorr_baseline.txt')
oh_2 = np.loadtxt('overhead_pair2_uncorr_AW.txt')
# correlation = 0.5
oh_3 = np.loadtxt('overhead_pair2_0.5corr_baseline.txt')
oh_4 = np.loadtxt('overhead_pair2_0.5corr_AW.txt')
# correlation = 0.99
oh_5 = np.loadtxt('overhead_pair2_0.99corr_baseline.txt')
oh_6 = np.loadtxt('overhead_pair2_0.99corr_AW.txt')

data_c2 = [oh_1,oh_3,oh_5]
data_d2 = [oh_2,oh_4,oh_6]
ticks = [r'$\rho=0$', r'$\rho=0.5$', r'$\rho=0.99$']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_c2, positions=np.array(range(len(data_c2)))*2.0-0.2, sym='', widths=0.4)
bpr = plt.boxplot(data_d2, positions=np.array(range(len(data_d2)))*2.0+0.2, sym='', widths=0.4)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='baseline SINN')
plt.plot([], c='#2C7BB6', label='loss-balanced SINN')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
# plt.ylim(0, 8)
plt.tight_layout()
